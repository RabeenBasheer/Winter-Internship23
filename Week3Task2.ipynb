# %%
import pandas as pd

# %%
data = pd.read_csv('/content/chipotle.tsv', sep='\t')
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
test = data.copy()
test
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
test.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
test=test.dropna(subset='choice_description')

# %%
test.isnull().sum()
# Out:
# order_id              0
# quantity              0
# item_name             0
# choice_description    0
# item_price            0
# dtype: int64

# %%
test['item_price']=test['item_price'].str.replace('$','')
test
# Out:
# <ipython-input-141-1803b26031ac>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   test['item_price']=test['item_price'].str.replace('$','')
# <ipython-input-141-1803b26031ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['item_price']=test['item_price'].str.replace('$','')
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...

# %%
test
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]      3.39
# 2                                               [Apple]      3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...     10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...     11.75
# ...

# %%
test[test.duplicated()]
# Out:
#       order_id  quantity            item_name  \
# 238        103         1        Steak Burrito
# 248        108         1          Canned Soda
# 297        129         1        Steak Burrito
# 381        165         1    Canned Soft Drink
# 484        205         1         Chicken Bowl
# 567        233         1    Canned Soft Drink
# 684        282         1    Canned Soft Drink
# 773        319         1         Chicken Bowl
# 908        376         1        Steak Burrito
# 924        381         1   Chicken Soft Tacos
# 1117       462         1      Chicken Burrito
# 1203       491         1      Chicken Burrito
# 1245       507         1    Canned Soft Drink
# 1381       561         1    Canned Soft Drink
# 1420       576         1        Barbacoa Bowl
# 1421       576         1  Barbacoa Salad Bowl
# 1502       610         1      Chicken Burrito
# 1612       651         1                 Izze
# 1791       724         1    Canned Soft Drink
# ...

# %%
test = test.drop_duplicates()
test
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]      3.39
# 2                                               [Apple]      3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...     10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...     11.75
# ...

# %%
test[test.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, quantity, item_name, choice_description, item_price]
# Index: []

# %%
unique_quantities = test['quantity'].unique()

unique_quantities
# Out:
# array([1, 2, 3, 4])

# %%
unique_prices = test['item_price'].unique()
unique_prices
# Out:
# array(['3.39 ', '16.98 ', '10.98 ', '11.75 ', '9.25 ', '8.75 ', '11.25 ',
#        '8.49 ', '2.18 ', '8.99 ', '1.09 ', '22.50 ', '11.48 ', '17.98 ',
#        '17.50 ', '1.25 ', '23.78 ', '6.49 ', '11.08 ', '22.16 ', '32.94 ',
#        '22.20 ', '10.58 ', '2.50 ', '23.50 ', '7.40 ', '18.50 ', '6.78 ',
#        '11.89 ', '9.39 ', '3.75 ', '8.69 ', '8.19 ', '35.00 ', '27.75 ',
#        '26.25 ', '21.96 ', '4.36 ', '22.96 ', '26.07 ', '12.98 ',
#        '35.25 ', '33.75 ', '16.38 ', '5.00 ', '8.50 ', '11.49 '],
#       dtype=object)

# %%
test['item_price'] = pd.to_numeric(test['item_price'])
test.dtypes
# Out:
# <ipython-input-148-3d5419f122a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['item_price'] = pd.to_numeric(test['item_price'])
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
test
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
test['choice_description']=test['choice_description'].str.replace('[','')
test['choice_description']=test['choice_description'].str.replace(']','')
test
# Out:
# <ipython-input-150-0fe3839aefb2>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   test['choice_description']=test['choice_description'].str.replace('[','')
# <ipython-input-150-0fe3839aefb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['choice_description']=test['choice_description'].str.replace('[','')
# <ipython-input-150-0fe3839aefb2>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# ...

# %%
test.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10, 6))
sns.scatterplot(x='quantity', y='item_price', data=test)
plt.title('Relationship between Quantity and Item Price')
plt.xlabel('Quantity')
plt.ylabel('Item Price')
plt.show()

# %%
test['quantity'].describe()
# Out:
# count    3335.000000
# mean        1.064168
# std         0.284718
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         4.000000
# Name: quantity, dtype: float64

# %%
test['item_price'].describe()
# Out:
# count    3335.000000
# mean        9.039520
# std         3.780434
# min         1.090000
# 25%         8.690000
# 50%         8.990000
# 75%        11.250000
# max        35.250000
# Name: item_price, dtype: float64

# %%
test
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 1                                            Clementine        3.39
# 2                                                 Apple        3.39
# 4     Tomatillo-Red Chili Salsa (Hot), Black Beans, ...       16.98
# 5     Fresh Tomato Salsa (Mild), Rice, Cheese, Sour ...       10.98
# 7     Tomatillo Red Chili Salsa, Fajita Vegetables, ...       11.75
# ...

# %%
data= test.copy()
data.to_csv('new_data.csv', sep=',', index=False)

# %%
from google.colab import files
files.download('new_data.csv')

# %%
test
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 1                                            Clementine        3.39
# 2                                                 Apple        3.39
# 4     Tomatillo-Red Chili Salsa (Hot), Black Beans, ...       16.98
# 5     Fresh Tomato Salsa (Mild), Rice, Cheese, Sour ...       10.98
# 7     Tomatillo Red Chili Salsa, Fajita Vegetables, ...       11.75
# ...
